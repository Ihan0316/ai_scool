# %%
# 이미지 그레이 스케일 적용 후, plt로 표시
import cv2
from matplotlib import pyplot as plt

img1 = cv2.imread('../../sample/pier39.JPG', cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread('../../sample/pier39.JPG', cv2.IMREAD_COLOR)

print('type(img1) : ', type(img1))
print('img1.dtype : ', img1.dtype)
print('img1.shape : ', img1.shape)
print('img2.shape : ', img2.shape)
h, w = img2.shape[:2]
print('img2.size: {} x {}'.format(w, h))

plt.figure(figsize=(20, 10))

plt.subplot(121), plt.axis('off'), plt.imshow(img1, cmap='gray'), plt.title('img1')
plt.subplot(122), plt.axis('off'), plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)), plt.title('img2')

plt.show()
# Out:
# type(img1) :  <class 'numpy.ndarray'>
# img1.dtype :  uint8
# img1.shape :  (480, 640)
# img2.shape :  (480, 640, 3)
# img2.size: 640 x 480

# %%
# 그레이 스케일의 shape 표시 및 plt 표시, 특정 영역 가리기
import sys
import cv2
from matplotlib import pyplot as plt

img1 = cv2.imread('../../sample/cat.jpg', cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread('../../sample/cat.jpg', cv2.IMREAD_COLOR)

h, w = img2.shape[:2]
print('img1.shape : ', img1.shape)
print('img2.shape : ', img2.shape)

for y in range(300, h):
    for x in range(300, w):
        img1[y, x] = 255
        img2[y, x] = (0, 0, 255)

img1[300:640, 300:640] = 255
img2[300:640, 300:640] = (0, 0, 255)

plt.figure(figsize=(20, 10))

plt.subplot(121), plt.axis('off'), plt.imshow(img1, cmap='gray'), plt.title('img1')
plt.subplot(122), plt.axis('off'), plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)), plt.title('img2')

plt.show()
# Out:
# img1.shape :  (640, 640)
# img2.shape :  (640, 640, 3)

# %%
# 밝기 연산
import cv2
from matplotlib import pyplot as plt

src = cv2.imread('../../sample/pier39.JPG', cv2.IMREAD_GRAYSCALE)

# 값이 255가 넘어가면 0부터 다시 시작 -> numpy 연산
dst1 = src + 100
# 값이 255가 넘어도 255 이상으로 넘어가지 않음 -> cv2 연산
dst2 = cv2.add(src, 100)

plt.figure(figsize=(20, 10))

plt.subplot(131), plt.axis('off'), plt.imshow(src, cmap='gray'), plt.title('src')
plt.subplot(132), plt.axis('off'), plt.imshow(dst1, cmap='gray'), plt.title('dst1 (src + 100)')
plt.subplot(133), plt.axis('off'), plt.imshow(dst2, cmap='gray'),plt.title('dst2 (cv2.add)')

plt.show()

# %%
# RGB 전부 100씩 밝기 증가
import cv2
from matplotlib import pyplot as plt

src = cv2.imread('../../sample/pier39.JPG')

dst = cv2.add(src, (100, 100, 100))

plt.figure(figsize=(20, 10))

plt.subplot(121), plt.axis('off'), plt.imshow(cv2.cvtColor(src, cv2.COLOR_BGR2RGB)), plt.title('src')
plt.subplot(122), plt.axis('off'), plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB)), plt.title('dst')

plt.show()

# %%
# 이미지 2장을 더해서 표시, 밝기 증가
import cv2
from matplotlib import pyplot as plt

src1 = cv2.imread('../../sample/cat.jpg', cv2.IMREAD_GRAYSCALE)
src2 = cv2.imread('../../sample/dog.jpg', cv2.IMREAD_GRAYSCALE)

dst = cv2.add(src1, src2)

plt.figure(figsize=(20, 10))

plt.subplot(131), plt.axis('off'), plt.imshow(src1, cmap='gray'), plt.title('cat')
plt.subplot(132), plt.axis('off'), plt.imshow(src2, cmap='gray'), plt.title('dog')
plt.subplot(133), plt.axis('off'), plt.imshow(dst, cmap='gray'), plt.title('dst')

plt.show()

# %%
# 이미지에서 값을 더하는 방법 -> 픽셀마다 값을 더하여 표시 (덧셈 기법) -> 값이 더해질 수록 밝기는 증가
import cv2
from matplotlib import pyplot as plt

src1 = cv2.imread('../../sample/cat.jpg', cv2.IMREAD_GRAYSCALE)
src2 = cv2.imread('../../sample/dog.jpg', cv2.IMREAD_GRAYSCALE)

dst1 = cv2.add(src1, src2)
# 얼마나 더할지 지정
dst2 = cv2.addWeighted(src1, 0.0, src2, 0.2, 0.0)
dst3 = cv2.addWeighted(src1, 0.5, src2, 0.5, 0.0)
dst4 = cv2.addWeighted(src1, 0.2, src2, 0.8, 0.0)

plt.figure(figsize=(20, 10))

plt.subplot(231), plt.axis('off'), plt.imshow(src1, cmap='gray'), plt.title('cat')
plt.subplot(232), plt.axis('off'), plt.imshow(src2, cmap='gray'), plt.title('dog')
plt.subplot(233), plt.axis('off'), plt.imshow(dst1, cmap='gray'), plt.title('add')
plt.subplot(234), plt.axis('off'), plt.imshow(dst2, cmap='gray'), plt.title('0.0_0.2')
plt.subplot(235), plt.axis('off'), plt.imshow(dst3, cmap='gray'), plt.title('0.5_0.5')
plt.subplot(236), plt.axis('off'), plt.imshow(dst4, cmap='gray'), plt.title('0.2_0.8')

plt.show()

# %%
# 이미지에서 다른 부분만 찾는 방법 -> 둘 사이의 차이를 표시(차이 연산)
import cv2
from matplotlib import pyplot as plt

src1 = cv2.imread('../../sample/abs1.jpg', cv2.IMREAD_GRAYSCALE)
src2 = cv2.imread('../../sample/abs2.jpg', cv2.IMREAD_GRAYSCALE)

dst = cv2.absdiff(src1, src2)

plt.figure(figsize=(20, 10))

plt.subplot(131), plt.axis('off'), plt.imshow(src1, 'gray'), plt.title('abs1')
plt.subplot(132), plt.axis('off'), plt.imshow(src2, 'gray'), plt.title('abs2')
plt.subplot(133), plt.axis('off'), plt.imshow(dst, 'gray'), plt.title('result')

plt.show()

# %%
# 컬러 이미지에서 RGB 값을 분리
import cv2
from matplotlib import pyplot as plt

image = cv2.imread('../../sample/candies.png')

b, g, r = cv2.split(image)

merge_b = cv2.merge([b, b, b])
merge_g = cv2.merge([g, g, g])
merge_r = cv2.merge([r, r, r])

plt.figure(figsize=(20, 10))

plt.subplot(221), plt.axis('off'), plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB)), plt.title('original')
plt.subplot(222), plt.axis('off'), plt.imshow(merge_b, cmap='gray'), plt.title('b')
plt.subplot(223), plt.axis('off'), plt.imshow(merge_g, cmap='gray'), plt.title('g')
plt.subplot(224), plt.axis('off'), plt.imshow(merge_r, cmap='gray'), plt.title('r')

plt.show()

# %%
# 컬러 이미지에서 HSV(색도, 명도, 채도) 값을 분리
import cv2
from matplotlib import pyplot as plt

image = cv2.imread('../../sample/candies.png')
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
h, s, v = cv2.split(hsv_image)

merge_h = cv2.merge([h, h, h])
merge_s = cv2.merge([s, s, s])
merge_v = cv2.merge([v, v, v])

plt.figure(figsize=(20, 10))

plt.subplot(221), plt.axis('off'), plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB)), plt.title('original')
plt.subplot(222), plt.axis('off'), plt.imshow(merge_h, cmap='gray'), plt.title('h')
plt.subplot(223), plt.axis('off'), plt.imshow(merge_s, cmap='gray'), plt.title('s')
plt.subplot(224), plt.axis('off'), plt.imshow(merge_v, cmap='gray'), plt.title('v')

plt.show()
