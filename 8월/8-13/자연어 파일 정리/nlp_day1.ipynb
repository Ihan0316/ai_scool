# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\gurwl\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\gurwl\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\gurwl\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\gurwl\anaconda3\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\gurwl\anaconda3\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\gurwl\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\gurwl\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\gurwl\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import konlpy

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\gurwl\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.tokenize import WordPunctTokenizer
from tensorflow.keras.preprocessing.text import text_to_word_sequence

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\gurwl\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
word_tokenize("Don't be fooled by the dark sounding name, Mr. Jone's Orphanage is as cheery as cheery goes for a pastry shop.")
# Out:
# ['Do',
#  "n't",
#  'be',
#  'fooled',
#  'by',
#  'the',
#  'dark',
#  'sounding',
#  'name',
#  ',',
#  'Mr.',
#  'Jone',
#  "'s",
#  'Orphanage',
#  'is',
#  'as',
#  'cheery',
#  'as',
#  'cheery',
#  'goes',
#  'for',
#  'a',
#  'pastry',
#  'shop',
#  '.']

# %%
WordPunctTokenizer().tokenize("Don't be fooled by the dark sounding name, Mr. Jone's Orphanage is as cheery as cheery goes for a pastry shop.")
# Out:
# ['Don',
#  "'",
#  't',
#  'be',
#  'fooled',
#  'by',
#  'the',
#  'dark',
#  'sounding',
#  'name',
#  ',',
#  'Mr',
#  '.',
#  'Jone',
#  "'",
#  's',
#  'Orphanage',
#  'is',
#  'as',
#  'cheery',
#  'as',
#  'cheery',
#  'goes',
#  'for',
#  'a',
#  'pastry',
#  'shop',
#  '.']

# %%
text_to_word_sequence("Don't be fooled by the dark sounding name, Mr. Jone's Orphanage is as cheery as cheery goes for a pastry shop.")
# Out:
# ["don't",
#  'be',
#  'fooled',
#  'by',
#  'the',
#  'dark',
#  'sounding',
#  'name',
#  'mr',
#  "jone's",
#  'orphanage',
#  'is',
#  'as',
#  'cheery',
#  'as',
#  'cheery',
#  'goes',
#  'for',
#  'a',
#  'pastry',
#  'shop']

# %%
from nltk.tokenize import TreebankWordTokenizer
t_tk=TreebankWordTokenizer()
t_tk.tokenize("Don't be fooled by the dark sounding name, Mr. Jone's Orphanage is as cheery as cheery goes for a pastry shop.")
# Out:
# ['Do',
#  "n't",
#  'be',
#  'fooled',
#  'by',
#  'the',
#  'dark',
#  'sounding',
#  'name',
#  ',',
#  'Mr.',
#  'Jone',
#  "'s",
#  'Orphanage',
#  'is',
#  'as',
#  'cheery',
#  'as',
#  'cheery',
#  'goes',
#  'for',
#  'a',
#  'pastry',
#  'shop',
#  '.']

# %%
from nltk.tokenize import sent_tokenize
doc="His barber kept his word. But keeping such a huge secret to himself was driving him crazy. Finally, the barber went up a mountain and almost to the edge of a cliff. He dug a hole in the midst of some reeds. He looked about, to make sure no one was near."
sent_tokenize(doc)
# Out:
# ['His barber kept his word.',
#  'But keeping such a huge secret to himself was driving him crazy.',
#  'Finally, the barber went up a mountain and almost to the edge of a cliff.',
#  'He dug a hole in the midst of some reeds.',
#  'He looked about, to make sure no one was near.']

# %%
sent_tokenize("Don't be fooled by the dark sounding name, Mr. Jone's Orphanage is as cheery as cheery goes for a pastry shop.")
# Out:
# ["Don't be fooled by the dark sounding name, Mr. Jone's Orphanage is as cheery as cheery goes for a pastry shop."]

# %%
한글='오늘 수업은 피곤 합니다. 내용이 어렵고 재미가 없나요? 그래도 우리는 수업을 해야 합니다.'
sent_tokenize(한글)
# Out:
# ['오늘 수업은 피곤 합니다.', '내용이 어렵고 재미가 없나요?', '그래도 우리는 수업을 해야 합니다.']

# %%
word_tokenize(한글)
# Out:
# ['오늘',
#  '수업은',
#  '피곤',
#  '합니다',
#  '.',
#  '내용이',
#  '어렵고',
#  '재미가',
#  '없나요',
#  '?',
#  '그래도',
#  '우리는',
#  '수업을',
#  '해야',
#  '합니다',
#  '.']

# %%
from konlpy.tag import Kkma
kkma=Kkma()
kkma.sentences(한글)
# Out:
# ['오늘 수업은 피곤 합니다.', '내용이 어렵고 재미가 없나요?', '그래도 우리는 수업을 해야 합니다.']

# %%
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

# %%
text="I am actively looking for Ph.D. students. and you are a Ph.D. student."
tk_w=word_tokenize(text)
tk_w
# Out:
# ['I',
#  'am',
#  'actively',
#  'looking',
#  'for',
#  'Ph.D.',
#  'students',
#  '.',
#  'and',
#  'you',
#  'are',
#  'a',
#  'Ph.D.',
#  'student',
#  '.']

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\gurwl\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
pos_tag(tk_w)
# Out:
# [('I', 'PRP'),
#  ('am', 'VBP'),
#  ('actively', 'RB'),
#  ('looking', 'VBG'),
#  ('for', 'IN'),
#  ('Ph.D.', 'NNP'),
#  ('students', 'NNS'),
#  ('.', '.'),
#  ('and', 'CC'),
#  ('you', 'PRP'),
#  ('are', 'VBP'),
#  ('a', 'DT'),
#  ('Ph.D.', 'NNP'),
#  ('student', 'NN'),
#  ('.', '.')]
